# %% [markdown]
# ## Welcome to the miRNA Heatmap. The goal of this project is as follows:
#
# 1) Display 8-length sequences of 'A', 'T', 'G', 'C', in a 2d map
#
# 2) create heatmap of known miRNA using the 2d array
#
# Lets import some librarys and then we can get started!

# %%
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt

import numpy as np
from numpy import loadtxt

from collections import Counter

from sklearn import preprocessing

SIZE = 7

# %% [markdown]
# The challenge of creating a 2D array of sequences is deciding how to organize it. We started by deciding that each corner would correspond to a particular nucleotide. To accomplish this, I created a fucntion that generates the different ATGC strings and sorts them according to the frequency of a given character. The Counter(str) function below counts the frequency of each character in the str, and adds it to an array if it is above a given threshold. Keep in mind, if the frequency of each character is the same, the first occuring character is considered the most frequent. By the nature of how the string are generated, this means that the same number of strings will be added to each array.
#
# Note the 'sorted()' function in the return line. This function sorts the array by frequency of a character, for example, if we are generating sequences with precedence 't', then 'tttttttt' would be sorted to the front of the list, followed by 'ttttttta' and 'tttttttc' and so on.

# %%
#Generate tables (the order of the char in arr will affect the list outputted)

def list_generate(char):
    arr = ['a','t','c','g']
    list_= []

    for a in arr:
        for b in arr:
            for c in arr:
                for d in arr:
                    for e in arr:
                        for f in arr:
                            for g in arr:
                                str = a+b+c+d+e+f+g
                                res = Counter(str)
                                res = max(res, key = res.get)
                                if(res==char):
                                    list_.append(str)
                                    
                                    
    #sort the array by char frequency

    return sorted(list_, key = lambda ele: -ele.count(char))

# %% [markdown]
# We now have 4 1d arrays containing all 65,536 sequences. In order to display them in a map, however, we have to convert the 1d arrays into a 2d representation. Because we have sorted them by frequency, we can fill a 2d array starting in the top left corner and filling in the diagnals, as shown in the picture below.
# ![fig%201.png](attachment:fig%201.png)
#
# To do this, we simply iterate through the table and sum(row, col). The sum(row, col) corresponds to the diagnals of the array, which we can fill linearly with the array from before.

# %%
#generate 2d array from 1d list, print to .csv
def map_generate(list_, table_size):
    map_ = [[0 for i in range(table_size)] for j in range(table_size)]
    counter = 0;
    number = 0
    
    while(number < table_size*2):
        for i in range(0,table_size):
            for j in range(0,table_size):
                if (j+i==number):
                    map_[i][j]=list_[counter]
                    counter+=1
        number+=1
    return map_

# %% [markdown]
# We now can print each array out in the form of a spreadsheet (.csv).

# %%
#print map
def print_map(filename, map_):
    df=pd.DataFrame(map_)
    df.to_csv(filename+'.csv', index= False, header = False)

# %% [markdown]
# We're almost done, however, due to the way we generated each 2d array, the top left corner of each spreadsheet contains the homopolymer ('tttttttt', 'cccccccc', 'gggggggg', 'aaaaaaaa') and gets filed outward from there. In order to complete the full map, we must rotate the spreadsheets to correspond to the 4 corners of the map. To do this, we use some simple matrix multiplication to rotate the spreadsheets.

# %%
#print 90 deg anticlockwise rotation of matrix
def rotate_map(map_, rotations):
    df= pd.DataFrame(map_)
    for i in range(0,rotations%4):
        df = df.T
        df = df.loc[::-1]
    return df

# %% [markdown]
# We're finally ready to generate the full map. To do this, we generate each map separately, then rotate the spreadsheets accordingly, and stitch them back together (ideally, I would write some code to stitch them together, but for now I just copy and paste them together manually. It wouldn't be that hard to write, I'm just lazy).

# %%
#
list_a = list_generate('a')
list_c = list_generate('c')
list_g = list_generate('g')
list_t = list_generate('t')

map_a = map_generate(list_a, 2**(SIZE-1))
map_c = map_generate(list_c, 2**(SIZE-1))
map_g = map_generate(list_g, 2**(SIZE-1))
map_t = map_generate(list_t, 2**(SIZE-1))

#rotate map_c 90°
map_c = rotate_map(map_c, 1)

#rotate map_t 180°
map_t = rotate_map(map_t, 2)

#rotate map_g 270°
map_g = rotate_map(map_g, 3)

print_map('arr_A', map_a)
print_map('arr_C', map_c)
print_map('arr_G', map_g)
print_map('arr_T', map_t)

# %% [markdown]
# Now that we have our completed spreadsheet, we can convert that into a heatmap using pyplot. Below are a few examples of what can be done with the data spreadsheet.

# %%
#function that takes in a character and an array and returns an array with the corresponding frequency of the given character
def map_degree_char(c, arr):
    map_ = [[0 for i in range(len(arr))] for j in range(len(arr))]
    for i in range(0, len(arr)):
        for j in range(0, len(arr[i])):
            map_[i][j] = Counter(arr[i][j])[c]
            
    return map_

# %%
#function that takes in an array and returns an array with character of greatest frequency
def map_degree(arr):
    map_ = [[0 for i in range(len(arr))] for j in range(len(arr))]
    for i in range(0, len(arr)):
        for j in range(0, len(arr[i])):
            res = Counter(arr[i][j])
            res = max(res, key = res.get) 
            map_[i][j] = Counter(arr[i][j])[res]
            
    return map_

# %%
df = pd.read_csv("AGTC-7seq.csv", header = None)
data = np.array(df)
data = map_degree(data)


fig = plt.figure(figsize=(25,25))
plt.imshow(data,cmap="inferno")
plt.rc('font', size=20)
plt.title("miRNA Max Heatmap")
plt.colorbar()
plt.savefig('miRNA Max Heatmap.png')
plt.show()

# %%
df = pd.read_csv("AGTC-7seq.csv", header = None)
data = np.array(df)
data = map_degree_char('t',data)

fig = plt.figure(figsize=(25,25))
plt.imshow(data,cmap="inferno")
plt.rc('font', size=20)
plt.title("miRNA Thymine Heatmap")
plt.colorbar()
plt.savefig('miRNA Thymine Heatmap.png')
plt.show()

# %% [markdown]
# ## Reading miRNA Data
# Our goal now is to take the data from [TargetScanHuman](https://www.targetscan.org/cgi-bin/targetscan/data_download.vert80.cgi) or from zebrafish_data.txt in the github folder. The format of this data will need to be processed into an array. We'll use the numpy loadtext:

# %%
zebrafish_data = loadtxt("zebrafish_data.txt", comments=">", delimiter="\z",dtype="str")


#this is just a formality, but we have to remove all sequences with the 'N' character for now
zebrafish_data = list(zebrafish_data)
print(len(zebrafish_data))
for i in zebrafish_data:
    if 'N' in i:
        zebrafish_data.remove(i)
print(len(zebrafish_data))
# Out:
# 20889
# 20834

# %% [markdown]
# We now have an array with elements of nucleotide sequences. Next, we have to count the frequency of each 8-character nucleotide sequence. To keep track of the numbers, lets first convert our 2D map into a 1D array and then convert that into a dictionary:

# %%
df = pd.read_csv("AGTC-7seq.csv", header = None)
data_arr = np.array(df).flatten()
print(data_arr)

data_dict = {data_arr[i]: 0 for i in range(0, len(data_arr))}
print(data_dict)
# Out:
# ['aaaaaaa' 'aaaaaat' 'aaaaaag' ... 'ttatttt' 'atttttt' 'ttttttt']
# {'aaaaaaa': 0, 'aaaaaat': 0, 'aaaaaag': 0, 'aaaaaga': 0, 'aaataaa': 0, 'aagaaaa': 0, 'gaaaaaa': 0, 'aaaaagt': 0, 'aaaatga': 0, 'aaaagag': 0, 'aaattaa': 0, 'aaacgaa': 0, 'aataaag': 0, 'aacaata': 0, 'aagaaga': 0, 'ataagaa': 0, 'acataaa': 0, 'agagaaa': 0, 'tagaaaa': 0, 'ctaaaaa': 0, 'ggaaaaa': 0, 'aaaagtg': 0, 'aaatcat': 0, 'aaactag': 0, 'aaagagg': 0, 'aataagt': 0, 'aattaga': 0, 'aacaacg': 0, 'aacttaa': 0, 'aagaagg': 0, 'aagcaag': 0, 'ataacat': 0, 'atagaag': 0, 'atgaaag': 0, 'acaagta': 0, 'actaaga': 0, 'agaaacg': 0, 'agactaa': 0, 'aggaaag': 0, 'taataag': 0, 'tacaata': 0, 'tcaaaga': 0, 'caaacag': 0, 'catataa': 0, 'ctgaaaa': 0, 'gaaatga': 0, 'gatataa': 0, 'gcaaaag': 0, 'aaatgct': 0, 'aaagcgg': 0, 'aattcta': 0, 'aatgcat': 0, 'aacttga': 0, 'aacgcac': 0, 'aagtcag': 0, 'aaggcca': 0, 'atacatt': 0, 'attaacc': 0, 'atcatca': 0, 'atgacta': 0, 'acaaggc': 0, 'acagagg': 0, 'actccaa': 0, 'acgaacc': 0, 'ccgttgg': 0, 'ctgatgg': 0, 'cagtcgg': 0, 'tggcgac': 0, 'tgcggat': 0, 'tgtaggc': 0, 'tcgggat': 0, 'tcaggag': 0, 'taggccg': 0, 'taagcgg': 0, 'aggtgat': 0, 'agccggt': 0, 'agtccgg': 0, 'acggcag': 0, 'actaggg': 0, 'atgatgg': 0, 'aagtgcg': 0, 'gggcgct': 0, 'gggtagc': 0, 'ggcgctg': 0, 'ggtggtt': 0, 'ggtagcg': 0, 'ggatggt': 0, 'gcggatg': 0, 'gctgggc': 0, 'gtggtgt': 0, 'gtcgggt': 0, 'gagggtc': 0, 'gagtgtg': 0, 'gattggg': 0, 'cgggagc': 0, 'cgcgggt': 0, 'cgatggg': 0, 'caggggc': 0, 'tgggtgt': 0, 'tggaggt': 0, 'tgtcggg': 0, 'tctgggg': 0, 'tagtggg': 0, 'agggagc': 0, 'aggaggt': 0, 'agtggtg': 0, 'acgggcg': 0, 'atgtggg': 0, 'gggggct': 0, 'ggggagc': 0, 'gggtgtg': 0, 'ggcggtg': 0, 'ggtcggg': 0, 'gcggggt': 0, 'gtggggt': 0, 'gaggggc': 0, 'gatgggg': 0, 'cggtggg': 0, 'tggggcg': 0, 'tgtgggg': 0, 'aggggtg': 0, 'agcgggg': 0, 'ggggggt': 0, 'ggggtgg': 0, 'ggcgggg': 0, 'gtggggg': 0, 'tgggggg': 0, 'ggggggg': 0, 'aaaaaac': 0, 'aaaaata': 0, 'aaaataa': 0, 'aaacaaa': 0, 'ataaaaa': 0, 'aaaaatt': 0, 'aaaaagc': 0, 'aaaacat': 0, 'aaaagta': 0, 'aaatcaa': 0, 'aaagaat': 0, 'aataata': 0, 'aacaaca': 0, 'aagataa': 0, 'atataaa': 0, 'acacaaa': 0, 'agtaaaa': 0, 'ttaaaaa': 0, 'ccaaaaa': 0, 'aaaattt': 0, 'aaaagct': 0, 'aaatcac': 0, 'aaactta': 0, 'aaagtat': 0, 'aataagc': 0, 'aatttaa': 0, 'aacaagt': 0, 'aactcaa': 0, 'aagatat': 0, 'aagcata': 0, 'ataacac': 0, 'atagata': 0, 'atgaata': 0, 'acaagca': 0, 'actataa': 0, 'agaaagt': 0, 'agaccaa': 0, 'aggaata': 0, 'taatata': 0, 'tacaaca': 0, 'tcaataa': 0, 'caaacta': 0, 'catacaa': 0, 'ccaaaat': 0, 'gaaacat': 0, 'gatacaa': 0, 'gcaaata': 0, 'aaatgcc': 0, 'aaaggtt': 0, 'aattcca': 0, 'aatgcac': 0, 'aactcat': 0, 'aacgcag': 0, 'aagtcta': 0, 'aaggcga': 0, 'atacatc': 0, 'attaacg': 0, 'atcatga': 0, 'atgacca': 0, 'acaaggg': 0, 'acagtat': 0, 'actcgaa': 0, 'acgaacg': 0, 'agaaccg': 0, 'cgaggca': 0, 'ccgtagg': 0, 'ctgaagg': 0, 'cagttgg': 0, 'tggcgat': 0, 'tgcggaa': 0, 'tgtagga': 0, 'tcgggaa': 0, 'tcagcgg': 0, 'taggctg': 0, 'taagtgg': 0, 'aggtcgc': 0, 'agccgga': 0, 'agtctgg': 0, 'acggtgc': 0, 'acagggc': 0, 'atcgggc': 0, 'aagtgtg': 0, 'gggcgca': 0, 'gggtagt': 0, 'ggcgcag': 0, 'ggtggta': 0, 'ggtagtg': 0, 'ggatgga': 0, 'gcggaag': 0, 'gctgggt': 0, 'gtggtga': 0, 'gtcggga': 0, 'gagggtt': 0, 'gagtgag': 0, 'gataggg': 0, 'cgggagt': 0, 'cgcggga': 0, 'cgaaggg': 0, 'caggggt': 0, 'tgggtga': 0, 'tggagga': 0, 'tgttggg': 0, 'tcagggg': 0, 'tagaggg': 0, 'agggagt': 0, 'aggagga': 0, 'agtggag': 0, 'acgggtg': 0, 'atgaggg': 0, 'gggggca': 0, 'ggggagt': 0, 'gggtgag': 0, 'ggcggag': 0, 'ggttggg': 0, 'gcgggga': 0, 'gtgggga': 0, 'gaggggt': 0, 'gaagggg': 0, 'cggaggg': 0, 'tggggtg': 0, 'tgagggg': 0, 'aggggag': 0, 'agtgggg': 0, 'gggggga': 0, 'ggggagg': 0, 'ggtgggg': 0, 'gaggggg': 0, 'agggggg': 0, 'aaaaaca': 0, 'aaaacaa': 0, 'aaagaaa': 0, 'acaaaaa': 0, 'aaaaatc': 0, 'aaaaagg': 0, 'aaaacac': 0, 'aaaagca': 0, 'aaatgaa': 0, 'aaagaac': 0, 'aataaca': 0, 'aacaaga': 0, 'aagacaa': 0, 'atacaaa': 0, 'acagaaa': 0, 'agcaaaa': 0, 'tcaaaaa': 0, 'cgaaaaa': 0, 'aaaattc': 0, 'aaaagcc': 0, 'aaatcag': 0, 'aaactca': 0, 'aaagtac': 0, 'aataagg': 0, 'aattcaa': 0, 'aacaagc': 0, 'aactgaa': 0, 'aagatac': 0, 'aagcaca': 0, 'ataacag' ...

# %% [markdown]
# Aight bet. Now that we have a dictionary, lets make a function with parameters (dict, str), and iterates through the string 8-characters at a time:

# %%
def sequence_count(string, dictionary, length):
    for i in range(len(string)-(length-1)):
        temp_seq = string[i:i+length].lower()
        dictionary[temp_seq]+= 1
    return dictionary

# %% [markdown]
# OMG too easy. Lets fill the dictionary with all of the values from the string sequences:

# %%
#1) Update the dictionary:
for i in zebrafish_data:
    data_dict= sequence_count(i,data_dict, SIZE)
print(data_dict)

#2) Convert dictionary back into 1D array
data_arr1 = np.array(list(data_dict.values()))
# Out:
# {'aaaaaaa': 44774, 'aaaaaat': 13158, 'aaaaaag': 9705, 'aaaaaga': 7528, 'aaataaa': 19721, 'aagaaaa': 8408, 'gaaaaaa': 9269, 'aaaaagt': 5996, 'aaaatga': 8232, 'aaaagag': 3490, 'aaattaa': 7617, 'aaacgaa': 1522, 'aataaag': 6903, 'aacaata': 4054, 'aagaaga': 3313, 'ataagaa': 2303, 'acataaa': 4191, 'agagaaa': 4265, 'tagaaaa': 3604, 'ctaaaaa': 4341, 'ggaaaaa': 4812, 'aaaagtg': 4394, 'aaatcat': 4502, 'aaactag': 2012, 'aaagagg': 1946, 'aataagt': 2641, 'aattaga': 1903, 'aacaacg': 552, 'aacttaa': 2988, 'aagaagg': 1494, 'aagcaag': 1541, 'ataacat': 2840, 'atagaag': 1234, 'atgaaag': 2883, 'acaagta': 1574, 'actaaga': 925, 'agaaacg': 1230, 'agactaa': 1386, 'aggaaag': 1712, 'taataag': 2084, 'tacaata': 3287, 'tcaaaga': 2257, 'caaacag': 2564, 'catataa': 2508, 'ctgaaaa': 5105, 'gaaatga': 4033, 'gatataa': 1908, 'gcaaaag': 1601, 'aaatgct': 4603, 'aaagcgg': 522, 'aattcta': 1837, 'aatgcat': 4351, 'aacttga': 2366, 'aacgcac': 667, 'aagtcag': 1908, 'aaggcca': 871, 'atacatt': 4345, 'attaacc': 1382, 'atcatca': 3472, 'atgacta': 1550, 'acaaggc': 786, 'acagagg': 1244, 'actccaa': 1193, 'acgaacc': 246, 'ccgttgg': 204, 'ctgatgg': 1507, 'cagtcgg': 321, 'tggcgac': 481, 'tgcggat': 397, 'tgtaggc': 683, 'tcgggat': 245, 'tcaggag': 1318, 'taggccg': 109, 'taagcgg': 259, 'aggtgat': 1105, 'agccggt': 274, 'agtccgg': 154, 'acggcag': 542, 'actaggg': 383, 'atgatgg': 1846, 'aagtgcg': 407, 'gggcgct': 274, 'gggtagc': 309, 'ggcgctg': 424, 'ggtggtt': 1145, 'ggtagcg': 173, 'ggatggt': 772, 'gcggatg': 591, 'gctgggc': 556, 'gtggtgt': 1587, 'gtcgggt': 190, 'gagggtc': 479, 'gagtgtg': 2775, 'gattggg': 736, 'cgggagc': 241, 'cgcgggt': 96, 'cgatggg': 193, 'caggggc': 456, 'tgggtgt': 1497, 'tggaggt': 1141, 'tgtcggg': 227, 'tctgggg': 770, 'tagtggg': 450, 'agggagc': 514, 'aggaggt': 706, 'agtggtg': 1181, 'acgggcg': 98, 'atgtggg': 1041, 'gggggct': 477, 'ggggagc': 326, 'gggtgtg': 1034, 'ggcggtg': 268, 'ggtcggg': 163, 'gcggggt': 228, 'gtggggt': 657, 'gaggggc': 359, 'gatgggg': 564, 'cggtggg': 243, 'tggggcg': 216, 'tgtgggg': 1080, 'aggggtg': 1127, 'agcgggg': 207, 'ggggggt': 550, 'ggggtgg': 803, 'ggcgggg': 421, 'gtggggg': 814, 'tgggggg': 746, 'ggggggg': 1185, 'aaaaaac': 7998, 'aaaaata': 12662, 'aaaataa': 14490, 'aaacaaa': 11675, 'ataaaaa': 10756, 'aaaaatt': 6014, 'aaaaagc': 3849, 'aaaacat': 8370, 'aaaagta': 4166, 'aaatcaa': 5151, 'aaagaat': 3498, 'aataata': 9900, 'aacaaca': 4763, 'aagataa': 2379, 'atataaa': 7438, 'acacaaa': 6233, 'agtaaaa': 4283, 'ttaaaaa': 13919, 'ccaaaaa': 4338, 'aaaattt': 4905, 'aaaagct': 3332, 'aaatcac': 2888, 'aaactta': 2395, 'aaagtat': 3386, 'aataagc': 1838, 'aatttaa': 6903, 'aacaagt': 2333, 'aactcaa': 3008, 'aagatat': 2766, 'aagcata': 1734, 'ataacac': 1733, 'atagata': 2914, 'atgaata': 4137, 'acaagca': 2188, 'actataa': 2120, 'agaaagt': 2394, 'agaccaa': 1447, 'aggaata': 1604, 'taatata': 5135, 'tacaaca': 2458, 'tcaataa': 3730, 'caaacta': 2464, 'catacaa': 2081, 'ccaaaat': 3470, 'gaaacat': 3009, 'gatacaa': 1252, 'gcaaata': 2512, 'aaatgcc': 2127, 'aaaggtt': 2666, 'aattcca': 1588, 'aatgcac': 2505, 'aactcat': 2237, 'aacgcag': 724, 'aagtcta': 1357, 'aaggcga': 310, 'atacatc': 1447, 'attaacg': 764, 'atcatga': 2154, 'atgacca': 1649, 'acaaggg': 741, 'acagtat': 3497, 'actcgaa': 552, 'acgaacg': 234, 'agaaccg': 342, 'cgaggca': 245, 'ccgtagg': 121, 'ctgaagg': 1732, 'cagttgg': 1257, 'tggcgat': 409, 'tgcggaa': 373, 'tgtagga': 1194, 'tcgggaa': 264, 'tcagcgg': 452, 'taggctg': 877, 'taagtgg': 1032, 'aggtcgc': 380, 'agccgga': 292, 'agtctgg': 960, 'acggtgc': 342, 'acagggc': 607, 'atcgggc': 188, 'aagtgtg': 2851, 'gggcgca': 211, 'gggtagt': 384, 'ggcgcag': 424, 'ggtggta': 508, 'ggtagtg': 609, 'ggatgga': 1790, 'gcggaag': 276, 'gctgggt': 869, 'gtggtga': 1235, 'gtcggga': 186, 'gagggtt': 885, 'gagtgag': 1383, 'gataggg': 288, 'cgggagt': 200, 'cgcggga': 100, 'cgaaggg': 215, 'caggggt': 1222, 'tgggtga': 1334, 'tggagga': 2214, 'tgttggg': 1395, 'tcagggg': 952, 'tagaggg': 692, 'agggagt': 621, 'aggagga': 1776, 'agtggag': 1179, 'acgggtg': 262, 'atgaggg': 1031, 'gggggca': 369, 'ggggagt': 496, 'gggtgag': 721, 'ggcggag' ...

# %% [markdown]
# All that's left now is to convert the data back into its original 2D array, and then print it as a map!

# %%
#Convert 1D array back into a 2D array
data_arr2 = np.reshape(data_arr1, (2**SIZE,2**SIZE))

#save the map as a csv
print_map('zebrafish_map', data_arr2)

#standardized the data with mean ans std, then putting it through a sigmoid function 
def sigmoid(x):
    e = np.exp(1)
    y = 1/(1+e**(-x))
    return y

data_arr2 = (data_arr2 - data_arr2.mean())/(data_arr2.std())

data_arr2 = sigmoid(data_arr2)
# Out:
# [[44774 13158  9705 ...   814   746  1185]
#  [ 7998 12662 14490 ...   725   710   747]
#  [11297 11330  9131 ...   489   698   204]
#  ...
#  [  637   913   992 ... 11108 11435 19513]
#  [  576   790   858 ... 18200 24475 18339]
#  [ 1773   831   883 ... 20030 16884 59657]]

# %%
#5) map 2D array
df = pd.read_csv("zebrafish_map.csv", header = None)
data = np.array(df)



fig = plt.figure(figsize=(25,25))
plt.imshow(data,cmap="seismic")
plt.title("zebrafish_map")
plt.colorbar()
plt.savefig('Zebrafish Sequence Map')
plt.show()

# %% [markdown]
# ## Post Script:
#
# The sequence data is pretty unique. In order to understand it better, I'm going to print out a table of tuples, with the sequece and value:

# %%
#convert dictionary to list of tuples
data_tuples1d = list(data_dict.items())

#Convert tuples into a list of strings
data_string1d = []
delimiter = ':'
for i in data_tuples1d:
    data_string1d.append(delimiter.join([str(value) for value in i]))

#convert strings into 2D array
data_string2d = np.reshape(data_string1d, (256,256))

print(data_string2d)

#save the map as a csv
print_map('Zebrafish Dictionary', data_string2d)
# Out:
# [['aaaaaaaa:27593' 'aaaaaaat:6866' 'aaaaaaag:5333' ... 'gtgggggg:173'
#   'tggggggg:276' 'gggggggg:674']
#  ['aaaaaaac:4583' 'aaaaaata:5182' 'aaaaataa:5597' ... 'ggtggggg:206'
#   'gagggggg:229' 'aggggggg:181']
#  ['aaaaaaca:4247' 'aaaaacaa:4379' 'aaaagaaa:4169' ... 'gggcgggg:286'
#   'ggaggggg:254' 'cggggggg:54']
#  ...
#  ['cacccccc:191' 'cccacccc:381' 'ccccctcc:356' ... 'ttttttgt:5619'
#   'ttttttta:9675' 'ttttattt:10150']
#  ['accccccc:221' 'ctcccccc:195' 'ccctcccc:268' ... 'ttttttat:6441'
#   'tttatttt:10705' 'tatttttt:7303']
#  ['cccccccc:1157' 'tccccccc:272' 'ccaccccc:234' ... 'ttattttt:8269'
#   'attttttt:8757' 'tttttttt:37096']]

# %%
#This tuple example is also very useful for the 4 cell idea we were thinking of, by maybe makig tuples I can print them out as columns and rows
#see example below:
#convert dictionary to list of tuples
data_tuples1 = list(data_dict.items())


#convert tuples into 2D array
data_tuples2 = np.reshape(data_tuples1, (256*2,256))

#save the map as a csv
print_map('Zebrafish Tuples', data_tuples2)
